# %% [markdown]
# # Multi-class Classification

# %% [markdown]
# ## 1.1 Goals
# - explore an example of multi-class classification using neural networks.

# %% [markdown]
# ## 1.2 Tools
# You will use some plotting routines. These are stored in `lab_utils_multiclass_TF.py` in this directory.

# %%
#this will get rid of any informational messages from TensorFlow indicating that it is optimized to use certain CPU instructions. 
# it won't affect the running of the code
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget
from sklearn.datasets import make_blobs
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
np.set_printoptions(precision=2)
from lab_utils_multiclass_TF import *
import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)
tf.autograph.set_verbosity(0)

# %% [markdown]
# # 2.0 Multi-class Classification
# Neural Networks are often used to classify data. Examples are neural networks:
# - take in photos and classify subjects in the photos as {dog,cat,horse,other}
# - take in a sentence and classify the 'parts of speech' of its elements: {noun, verb, adjective etc..}
#
# A network of this type will have multiple units in its final layer. Each output is associated with a category. When an input example is applied to the network, the output with the highest value is the category predicted. If the output is applied to a softmax function, the output of the softmax will provide probabilities of the input being in each category.
#
# Let's start by creating a four-class data set.

# %% [markdown]
# ## 2.1 Prepare and visualize our data
# We will use Scikit-Learn `make_blobs` function to make a training data set with 4 categories as shown in the plot below.

# %%
# make 4-class dataset for classification
classes = 4
m = 100
centers = [[-5, 2], [-2, -2], [1, 2], [5, -2]]
std = 1.0
X_train, y_train = make_blobs(n_samples=m, centers=centers, cluster_std=std,random_state=30)

# %%
plt_mc(X_train,y_train,classes, centers, std=std)
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# Each dot represents a training example. The axis (x0,x1) are the inputs and the color represents the class the example is associated with. Once trained, the model will be presented with a new example, (x0,x1), and will predict the class.
#
# While generated, this data set is representative of many real-world classification problems. There are several input features (x0,...,xn) and several output categories. The model is trained to use the input features to predict the correct output category.

# %%
# show classes in data set
print(f"unique classes {np.unique(y_train)}")
# show how classes are represented
print(f"class representation {y_train[:10]}")
# show shapes of our dataset
print(f"shape of X_train: {X_train.shape}, shape of y_train: {y_train.shape}")
# Out:
# unique classes [0 1 2 3]
# class representation [3 3 3 0 3 3 3 3 2 0]
# shape of X_train: (100, 2), shape of y_train: (100,)

# %% [markdown]
# ## 2.2 Model
#
# We will use a 2-layer network as shown.
# Unlike binary classification networks, this network has four outputs, one for each class. Given an input example, the output with the highest value is the predicted class of the input.
#
# Below is an example of how to construct this network in Tensorflow. Notice the output layer uses a `linear` rather than a `softmax` activation. While it is possible to include the softmax in the output layer, it is more numerically stable if linear outputs are passed to the loss function during training. If the model is used to predict probabilities, the softmax can be applied at that point.
#
# - Note: softmax demonstration is given in the repository

# %%
tf.random.set_seed(1234)  # applied to achieve consistent results
model = Sequential(
    [
        Dense(2, activation = 'relu',   name = "L1"),
        Dense(4, activation = 'linear', name = "L2")
    ]
)

# %% [markdown]
# The statements below compile and train the network. Setting `from_logits=True` as an argument to the loss function specifies that the output activation was linear rather than a softmax.

# %%
model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=tf.keras.optimizers.Adam(0.01),
)

model.fit(
    X_train,y_train,
    epochs=200
)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 1s 4ms/step - loss: 2.4182
# Epoch 2/200
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2047
# Epoch 3/200
# 4/4 [==============================] - 0s 2ms/step - loss: 2.0219
# Epoch 4/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.8710
# Epoch 5/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7110
# Epoch 6/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5836
# Epoch 7/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4517
# Epoch 8/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3372
# Epoch 9/200
# 4/4 [==============================] - 0s 27ms/step - loss: 1.2365
# Epoch 10/200
# 4/4 [==============================] - 0s 2ms/step - loss: 1.1472
# Epoch 11/200
# 4/4 [==============================] - 0s 28ms/step - loss: 1.0633
# Epoch 12/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.9870
# Epoch 13/200
# 4/4 [==============================] - 0s 29ms/step - loss: 0.9210
# Epoch 14/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8559
# Epoch 15/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.8072
# Epoch 16/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7674
# Epoch 17/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.7313
# Epoch 18/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6998
# Epoch 19/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6733
# Epoch 20/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6500
# Epoch 21/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6270
# Epoch 22/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6102
# Epoch 23/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5942
# Epoch 24/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5805
# Epoch 25/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5680
# Epoch 26/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5554
# Epoch 27/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.5429
# Epoch 28/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5313
# Epoch 29/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.5212
# Epoch 30/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5120
# Epoch 31/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.5030
# Epoch 32/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4956
# Epoch 33/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.4874
# Epoch 34/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4787
# Epoch 35/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.4705
# Epoch 36/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4611
# Epoch 37/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4534
# Epoch 38/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4459
# Epoch 39/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4393
# Epoch 40/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.4334
# Epoch 41/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4267
# Epoch 42/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.4218
# Epoch 43/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4165
# Epoch 44/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.4109
# Epoch 45/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4053
# Epoch 46/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.3994
# Epoch 47/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3953
# Epoch 48/200
# 4/4 [==============================] - 0s 26ms/step - loss: 0.3913
# Epoch 49/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3858
# Epoch 50/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.3822
# Epoch 51/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3781
# Epoch 52/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3736
# Epoch 53/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3693
# Epoch 54/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3652
# Epoch 55/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.3612
# Epoch 56/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3573
# Epoch 57/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3546
# Epoch 58/200
# 4/4 [==============================] - 0s 26ms/step - loss: 0.3508
# Epoch 59/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3477
# Epoch 60/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3443
# Epoch 61/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3403
# Epoch 62/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3371
# Epoch 63/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.3342
# Epoch 64/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3304
# Epoch 65/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3273
# Epoch 66/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.3241
# Epoch 67/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3212
# Epoch 68/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3189
# Epoch 69/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3159
# Epoch 70/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3135
# Epoch 71/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.3107
# Epoch 72/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3088
# Epoch 73/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3062
# Epoch 74/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3037
# Epoch 75/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3008
# Epoch 76/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.2988
# Epoch 77/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2966
# Epoch 78/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2944
# Epoch 79/200
# 4/4 [==============================] - 0s 26ms/step - loss: 0.2928
# Epoch 80/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2910
# Epoch 81/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.2885
# Epoch 82/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2839
# Epoch 83/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2810
# Epoch 84/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.2789
# Epoch 85/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2765
# Epoch 86/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.2773
# Epoch 87/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2762
# Epoch 88/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2732
# Epoch 89/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2678
# Epoch 90/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2640
# Epoch 91/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.2603
# Epoch 92/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2568
# Epoch 93/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.2520
# Epoch 94/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2467
# Epoch 95/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.2420
# Epoch 96/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2370
# Epoch 97/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.2301
# Epoch 98/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2251
# Epoch 99/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.2207
# Epoch 100/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2146
# Epoch 101/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.2090
# Epoch 102/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2024
# Epoch 103/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.1964
# Epoch 104/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1900
# Epoch 105/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.1864
# Epoch 106/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1819
# Epoch 107/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1756
# Epoch 108/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1677
# Epoch 109/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1600
# Epoch 110/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.1564
# Epoch 111/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1505
# Epoch 112/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.1454
# Epoch 113/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1406
# Epoch 114/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.1359
# Epoch 115/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1319
# Epoch 116/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.1283
# Epoch 117/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1250
# Epoch 118/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.1217
# Epoch 119/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1190
# Epoch 120/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.1164
# Epoch 121/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1137
# Epoch 122/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.1117
# Epoch 123/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1093
# Epoch 124/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1065
# Epoch 125/200
# 4/4 [==============================] - 0s 26ms/step - loss: 0.1034
# Epoch 126/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0989
# Epoch 127/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0961
# Epoch 128/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0937
# Epoch 129/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0910
# Epoch 130/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0880
# Epoch 131/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0855
# Epoch 132/200
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0825
# Epoch 133/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0807
# Epoch 134/200
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0784
# Epoch 135/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0765
# Epoch 136/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0745
# Epoch 137/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0729
# Epoch 138/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0712
# Epoch 139/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0699
# Epoch 140/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0683
# Epoch 141/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0671
# Epoch 142/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0657
# Epoch 143/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0641
# Epoch 144/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0629
# Epoch 145/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0614
# Epoch 146/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0602
# Epoch 147/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0592
# Epoch 148/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0580
# Epoch 149/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0571
# Epoch 150/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0561
# Epoch 151/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0550
# Epoch 152/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0540
# Epoch 153/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0531
# Epoch 154/200
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0523
# Epoch 155/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0514
# Epoch 156/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0505
# Epoch 157/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0497
# Epoch 158/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0486
# Epoch 159/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0477
# Epoch 160/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0469
# Epoch 161/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0461
# Epoch 162/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0452
# Epoch 163/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0443
# Epoch 164/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0435
# Epoch 165/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0432
# Epoch 166/200
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0425
# Epoch 167/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0420
# Epoch 168/200
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0414
# Epoch 169/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0406
# Epoch 170/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0399
# Epoch 171/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0391
# Epoch 172/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0385
# Epoch 173/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0378
# Epoch 174/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0372
# Epoch 175/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0367
# Epoch 176/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0360
# Epoch 177/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0354
# Epoch 178/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0348
# Epoch 179/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0346
# Epoch 180/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0340
# Epoch 181/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0336
# Epoch 182/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0332
# Epoch 183/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0328
# Epoch 184/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0325
# Epoch 185/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0321
# Epoch 186/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0317
# Epoch 187/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0313
# Epoch 188/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0311
# Epoch 189/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0307
# Epoch 190/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0304
# Epoch 191/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0300
# Epoch 192/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0297
# Epoch 193/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0293
# Epoch 194/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0290
# Epoch 195/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0286
# Epoch 196/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0283
# Epoch 197/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0280
# Epoch 198/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0277
# Epoch 199/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0274
# Epoch 200/200
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0271

# %% [markdown]
# With the model trained, we can see how the model has classified the training data.

# %%
plt_cat_mc(X_train, y_train, model, classes)
# Out:
# 184/184 [==============================] - 1s 3ms/step
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# Above, the decision boundaries show how the model has partitioned the input space.  This very simple model has had no trouble classifying the training data. Let's look at the network in more detail.
#
# Below, we will pull the trained weights from the model and use that to plot the function of each of the network units. Further down, there is a more detailed explanation of the results.

# %%
# gather the trained parameters from the first layer
l1 = model.get_layer("L1")
W1,b1 = l1.get_weights()

# %%
# plot the function of the first layer
plt_layer_relu(X_train, y_train.reshape(-1,), W1, b1, classes)
# Out:
# /home/jupyter/ML/Multiclass_TensorFlow/lab_utils_multiclass_TF.py:64: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# /home/jupyter/ML/Multiclass_TensorFlow/lab_utils_multiclass_TF.py:64: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
# gather the trained parameters from the output layer
l2 = model.get_layer("L2")
W2, b2 = l2.get_weights()
# create the 'new features', the training examples after L1 transformation
Xl2 = np.maximum(0, np.dot(X_train,W1) + b1)

plt_output_layer_linear(Xl2, y_train.reshape(-1,), W2, b2, classes,
                        x0_rng = (-0.25,np.amax(Xl2[:,0])), x1_rng = (-0.25,np.amax(Xl2[:,1])))
# Out:
# /home/jupyter/ML/Multiclass_TensorFlow/lab_utils_multiclass_TF.py:64: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# /home/jupyter/ML/Multiclass_TensorFlow/lab_utils_multiclass_TF.py:64: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# /home/jupyter/ML/Multiclass_TensorFlow/lab_utils_multiclass_TF.py:64: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# /home/jupyter/ML/Multiclass_TensorFlow/lab_utils_multiclass_TF.py:64: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# ## Explanation
# #### Layer 1
# These plots show the function of Units 0 and 1 in the first layer of the network. The inputs are ($x_0,x_1$) on the axis. The output of the unit is represented by the color of the background. This is indicated by the color bar on the right of each graph. Notice that since these units are using a ReLu, the outputs do not necessarily fall between 0 and 1 and in this case are greater than 20 at their peaks.
# The contour lines in this graph show the transition point between the output, $a^{[1]}_j$ being zero and non-zero. The contour line in the graph is the inflection point in the ReLu.
#
# Unit 0 has separated classes 0 and 1 from classes 2 and 3. Points to the left of the line (classes 0 and 1) will output zero, while points to the right will output a value greater than zero.
# Unit 1 has separated classes 0 and 2 from classes 1 and 3. Points above the line (classes 0 and 2 ) will output a zero, while points below will output a value greater than zero. Let's see how this works out in the next layer!

# %% [markdown]
# #### Layer 2, the output layer
# The dots in these graphs are the training examples translated by the first layer. One way to think of this is the first layer has created a new set of features for evaluation by the 2nd layer. The axes in these plots are the outputs of the previous layer $a^{[1]}_0$ and $a^{[1]}_1$. As predicted above, classes 0 and 1 (blue and green) have  $a^{[1]}_0 = 0$ while classes 0 and 2 (blue and orange) have $a^{[1]}_1 = 0$.
# Once again, the intensity of the background color indicates the highest values.
# Unit 0 will produce its maximum value for values near (0,0), where class 0 (blue) has been mapped.
# Unit 1 produces its highest values in the upper left corner selecting class 1 (green).
# Unit 2 targets the lower right corner where class 2 (orange) resides.
# Unit 3 produces its highest values in the upper right selecting our final class (purple).
#
# One other aspect that is not obvious from the graphs is that the values have been coordinated between the units. It is not sufficient for a unit to produce a maximum value for the class it is selecting for, it must also be the highest value of all the units for points in that class. This is done by the implied softmax function that is part of the loss function (`SparseCategoricalCrossEntropy`). Unlike other activation functions, the softmax works across all the outputs.
